# %%
# importing libraries
import numpy as np  # For numerical computation
import pandas as pd  # Data manipulation
import seaborn as sns  # plotting
import scipy.io  # reading matlab files in python
from scipy import signal  #signal processing
from scipy.fftpack import fft, dct  #signal processing

from sklearn.linear_model import LinearRegression  #linear regression model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, train_test_split  # cross validation split
from sklearn.metrics import mean_squared_error
import warnings

warnings.filterwarnings('ignore')

from matplotlib import pyplot as plt  # For plotting graphs(Visualization)

import os  # system-wide functions

os.listdir('./kaggle_data')
# Out:
# ['part_1.mat',
#  'part_10.mat',
#  'part_11.mat',
#  'part_12.mat',
#  'part_2.mat',
#  'part_3.mat',
#  'part_4.mat',
#  'part_5.mat',
#  'part_6.mat',
#  'part_7.mat',
#  'part_8.mat',
#  'part_9.mat',
#  'Samples']

# %% [markdown]
# ### Data Preparation

# %%
# defining our evaluation error function
def rmse(y_true, y_pred):
    """Computes the Root Mean Squared Error (RMSE)."""
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
sample_file = scipy.io.loadmat(f'./kaggle_data/part_{1}.mat')
print(f'sample_file Data type: {type(sample_file)}')
print(f'sample_file keys:\n{sample_file.keys()}')
# Out:
# sample_file Data type: <class 'dict'>
# sample_file keys:
# dict_keys(['__header__', '__version__', '__globals__', 'p'])

# %%
# Loading a sample .mat file to understand the data dimensions
test_sample = scipy.io.loadmat(f'./kaggle_data/part_{1}.mat')['p']
print(f'test_sample Data type: {type(test_sample)}')
print(f'test_sample shape/dimensions: {test_sample.shape}')
# Out:
# test_sample Data type: <class 'numpy.ndarray'>
# test_sample shape/dimensions: (1, 1000)

# %%
print(f"Total Samples: {len(test_sample[0])}")
print(f"Number of readings in each sample(column): {len(test_sample[0][0])}")
print(f"Number of samples in each reading(ECG): {len(test_sample[0][0][2])}")

temp_mat = test_sample[0, 999]
temp_length = temp_mat.shape[1]
sample_size = 125

print(temp_length)
print((int)(temp_length / sample_size))
# Out:
# Total Samples: 1000
# Number of readings in each sample(column): 3
# Number of samples in each reading(ECG): 61000
# 9000
# 72

# %%
sample_size = 125
ppg = []
for i in range(1000):
    temp_mat = test_sample[0, i]
    temp_length = temp_mat.shape[1]
    for j in range((int)(temp_length / sample_size)):
        temp_ppg = temp_mat[0, j * sample_size:(j + 1) * sample_size]
        ppg.append(temp_ppg)

# %%
ecg = []
bp = []
sbp = []  #Systolic Blood Pressure
dbp = []  #Diastolic Blood Pressue
size = 125  #sample size

for i in range(1000):
    temp_mat = test_sample[0, i]
    temp_length = temp_mat.shape[1]
    for j in range((int)(temp_length / sample_size)):
        temp_ecg = temp_mat[2, j * size:(j + 1) * size]
        temp_bp = temp_mat[1, j * size:(j + 1) * size]

        max_value = max(temp_bp)
        min_value = min(temp_bp)

        sbp.append(max_value)
        dbp.append(min_value)
        ecg.append(temp_ecg)
        bp.append(temp_bp)

# %%
# Reshaping the ecg, ppg and bp signal data into column vectors
ppg, ecg, bp = np.array(ppg).reshape(-1,1), np.array(ecg).reshape(-1,1), np.array(bp).reshape(-1,1)
sbp, dbp = np.array(sbp).reshape(-1,1), np.array(dbp).reshape(-1,1)
print(f'PPG_shape: {ppg.shape}\n ECG_shape: {ecg.shape}\n BP_shape: {bp.shape}')
print(f'Systolic-BP_shape: {sbp.shape},\n Diastolic-BP_shape: {dbp.shape}')
# Out:
# PPG_shape: (32061000, 1)
#  ECG_shape: (32061000, 1)
#  BP_shape: (32061000, 1)
# Systolic-BP_shape: (256488, 1),
#  Diastolic-BP_shape: (256488, 1)

# %% [markdown]
# ### plotting sample ppg, ecg and bp signals

# %%
##using a sample size of 125
fig, ax = plt.subplots(3,1, figsize=(9,12), sharex=True)

ax[0].set_title('PPG graph', fontsize=16)
ax[0].set_ylabel('Signal Value')
ax[0].plot(ppg[:125])

ax[1].set_title('ECG graph', fontsize=16)
ax[1].set_ylabel('Signal Value')
ax[1].plot(ecg[:125])

ax[2].set_title('Blood Pressure (BP) graph', fontsize=16)
ax[2].set_ylabel('Signal Value')
ax[2].set_xlabel('Sample size')
ax[2].plot(bp[:125])

# %%
## Visualizing SBP and DBP
#fig, ax = plt.subplots(1,1, figsize=(9,12))

plt.title('SBP vs DBP graph', fontsize=16)
plt.ylabel('Signal Value')
plt.plot(sbp[:125])
plt.plot(dbp[:125])
plt.legend(['SBP', 'DBP'])

# %% [markdown]
# #### Statistical Correlation of signals

# %% [markdown]
# Computing and Visualizing the Cross correlation of PPG and BP signals

# %%
# Computing the cross correlation of ppg and bp signals
cross_corr = np.convolve(ppg[:125].squeeze(), bp[:125].squeeze(), mode='full')

fig, ax = plt.subplots(3,1, figsize=(9,12), sharex=True)

ax[0].set_title('PPG graph', fontsize=16)
ax[0].set_ylabel('Signal Value')
ax[0].plot(ppg[:125])

ax[1].set_title('BP graph', fontsize=16)
ax[1].set_ylabel('Signal Value')
ax[1].plot(bp[:125])

ax[2].set_title('Cross-correlated resultant graph', fontsize=16)
ax[2].set_ylabel('Signal Value')
ax[2].set_xlabel('Sample size')
ax[2].plot(cross_corr[:125])

# %%
#Computing the discrete cosine transform (DCT)
cosine_transformed_array = dct(ppg)
error = rmse(bp.squeeze(), cosine_transformed_array.squeeze())
print(f'RMSE: {error}')
# Out:
# RMSE: 92.6029607182544

# %% [markdown]
# Approach 1: linear regression model

# %%
# creating train and test sets
X_train, X_test, y_train, y_test = train_test_split(ppg, bp, test_size=0.30)

# %%
# Kfold cross-validation
folds = KFold(n_splits=5, shuffle=False)
scores = []
for i, (train_index, val_index) in enumerate(folds.split(X_train, y_train)):
    train_data, target = X_train[train_index], y_train[train_index]
    validation_data, val_target = X_train[val_index], y_train[val_index]
    
    model = LinearRegression()
    model.fit(train_data, target)
    # model = RandomForestRegressor(n_estimators=50,max_depth=5, n_jobs=-1, random_state=42)
    # model.fit(train_data[:100000], target[:100000].squeeze())  # training on few samples to save time.
    val_predictions = model.predict(validation_data)
    error = rmse(val_target, val_predictions)
    scores.append(error)
    print(f'Fold {i} RMSE: {error}')
print(f'Average RMSE over 5 folds: {np.mean(scores)}')
# Out:
# Fold 0 RMSE: 27.337521649622467
# Fold 1 RMSE: 27.359058404828804
# Fold 2 RMSE: 27.33810257837128
# Fold 3 RMSE: 27.34576665397457
# Fold 4 RMSE: 27.34725567710186
# Average RMSE over 5 folds: 27.345540992779796

# %%
# Visualizing train error.
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
ax[0].set_title("=======Training error=======")
ax[0].set_xlabel('Number of folds')
ax[0].set_ylabel('Error values')
ax[0].plot(scores)

# Visualize predicted BP and the True BP
ax[1].set_title("===True BP values Vs Predicted BP values===")
ax[1].set_xlabel('Number of samples taken')
ax[1].set_ylabel('BP values')
ax[1].plot(val_target[:100])  #only plotting 100 samples
ax[1].plot(val_predictions[:100])
ax[1].legend(['True_BP', 'Predicted_BP'])

# %% [markdown]
# ## Tryout: Pycaret

# %%
import pycaret
import sklearn

print(pycaret.__version__)
print(sklearn.__version__)
# Out:
# 2.3.10
# 0.23.2

# %%
from pycaret.regression import *

# %%
data = pd.DataFrame(np.concatenate((ppg, bp), axis=1))
data.columns = ['PPG', 'BP']

# %%
data
# Out:
#                PPG          BP
# 0         1.759531   67.062955
# 1         1.718475   69.358628
# 2         1.684262   75.366453
# 3         1.657869   85.037586
# 4         1.637341   96.222885
# ...            ...         ...
# 32060995  1.413490  123.135987
# 32060996  1.400782  120.889158
# 32060997  1.386119  118.495797
# 32060998  1.368524  116.053592
# 32060999  1.352884  113.611387
#
# [32061000 rows x 2 columns]

# %%
# split data into train-test set of 70 and 30 percent respectively
train = data[data.index < 22060995]
test = data[data.index >= 22060995]

# check shape
train.shape, test.shape
# Out:
# ((22060995, 2), (10000005, 2))

# %%
# initialize setup
s = setup(data=train,
          test_data=test,
          target='BP',
          fold_strategy='timeseries',
          fold=5,
          transform_target=True,
          session_id=123)
# Out:
# <style type="text/css">
# #T_7814f_row42_col1, #T_7814f_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7814f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7814f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7814f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7814f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7814f_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7814f_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7814f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7814f_row1_col1" class="data row1 col1" >BP</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7814f_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_7814f_row2_col1" class="data row2 col1" >(22060995, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7814f_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_7814f_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7814f_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_7814f_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7814f_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_7814f_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7814f_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_7814f_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7814f_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_7814f_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7814f_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_7814f_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7814f_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_7814f_row9_col1" class="data row9 col1" >(22060995, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7814f_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_7814f_row10_col1" class="data row10 col1" >(10000005, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7814f_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_7814f_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7814f_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_7814f_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7814f_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_7814f_row13_col1" class="data row13 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7814f_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_7814f_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7814f_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_7814f_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7814f_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_7814f_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7814f_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_7814f_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7814f_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_7814f_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7814f_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_7814f_row19_col1" class="data row19 col1" >67c4</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7814f_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_7814f_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7814f_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_7814f_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7814f_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_7814f_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7814f_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_7814f_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_7814f_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_7814f_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_7814f_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_7814f_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_7814f_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_7814f_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_7814f_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_7814f_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_7814f_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_7814f_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_7814f_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_7814f_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7814f_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_7814f_row30_col0" class="data row30 col0" >Transformation Method</td>

# %%
best = compare_models(sort='MAE')
# Out:
# <style type="text/css">
# #T_d2c4f th {
#   text-align: left;
# }
# #T_d2c4f_row0_col0, #T_d2c4f_row1_col0, #T_d2c4f_row1_col1, #T_d2c4f_row1_col2, #T_d2c4f_row1_col3, #T_d2c4f_row2_col0, #T_d2c4f_row2_col1, #T_d2c4f_row2_col2, #T_d2c4f_row2_col3, #T_d2c4f_row3_col0, #T_d2c4f_row3_col1, #T_d2c4f_row3_col2, #T_d2c4f_row3_col3, #T_d2c4f_row3_col4, #T_d2c4f_row4_col0, #T_d2c4f_row4_col1, #T_d2c4f_row4_col2, #T_d2c4f_row4_col3, #T_d2c4f_row4_col4, #T_d2c4f_row4_col5, #T_d2c4f_row5_col0, #T_d2c4f_row5_col1, #T_d2c4f_row5_col2, #T_d2c4f_row5_col3, #T_d2c4f_row5_col4, #T_d2c4f_row6_col0, #T_d2c4f_row6_col1, #T_d2c4f_row6_col2, #T_d2c4f_row6_col3, #T_d2c4f_row6_col4, #T_d2c4f_row7_col0, #T_d2c4f_row7_col1, #T_d2c4f_row7_col2, #T_d2c4f_row7_col3, #T_d2c4f_row7_col4, #T_d2c4f_row7_col5, #T_d2c4f_row7_col6, #T_d2c4f_row8_col0, #T_d2c4f_row8_col1, #T_d2c4f_row8_col2, #T_d2c4f_row8_col3, #T_d2c4f_row8_col4, #T_d2c4f_row8_col5, #T_d2c4f_row8_col6, #T_d2c4f_row9_col0, #T_d2c4f_row9_col1, #T_d2c4f_row9_col2, #T_d2c4f_row9_col3, #T_d2c4f_row9_col4, #T_d2c4f_row9_col5, #T_d2c4f_row9_col6, #T_d2c4f_row10_col0, #T_d2c4f_row10_col1, #T_d2c4f_row10_col2, #T_d2c4f_row10_col3, #T_d2c4f_row10_col4, #T_d2c4f_row10_col5, #T_d2c4f_row10_col6, #T_d2c4f_row11_col0, #T_d2c4f_row11_col1, #T_d2c4f_row11_col2, #T_d2c4f_row11_col3, #T_d2c4f_row11_col4, #T_d2c4f_row11_col5, #T_d2c4f_row11_col6, #T_d2c4f_row12_col0, #T_d2c4f_row12_col1, #T_d2c4f_row12_col2, #T_d2c4f_row12_col3, #T_d2c4f_row12_col4, #T_d2c4f_row12_col5, #T_d2c4f_row12_col6, #T_d2c4f_row13_col0, #T_d2c4f_row13_col1, #T_d2c4f_row13_col2, #T_d2c4f_row13_col3, #T_d2c4f_row13_col4, #T_d2c4f_row13_col5, #T_d2c4f_row13_col6, #T_d2c4f_row14_col0, #T_d2c4f_row14_col1, #T_d2c4f_row14_col2, #T_d2c4f_row14_col3, #T_d2c4f_row14_col4, #T_d2c4f_row14_col5, #T_d2c4f_row14_col6, #T_d2c4f_row15_col0, #T_d2c4f_row15_col1, #T_d2c4f_row15_col2, #T_d2c4f_row15_col3, #T_d2c4f_row15_col4, #T_d2c4f_row15_col5, #T_d2c4f_row15_col6, #T_d2c4f_row16_col0, #T_d2c4f_row16_col1, #T_d2c4f_row16_col2, #T_d2c4f_row16_col3, #T_d2c4f_row16_col4, #T_d2c4f_row16_col5, #T_d2c4f_row16_col6, #T_d2c4f_row17_col0, #T_d2c4f_row17_col1, #T_d2c4f_row17_col2, #T_d2c4f_row17_col3, #T_d2c4f_row17_col4, #T_d2c4f_row17_col5, #T_d2c4f_row17_col6, #T_d2c4f_row18_col0, #T_d2c4f_row18_col1, #T_d2c4f_row18_col2, #T_d2c4f_row18_col3, #T_d2c4f_row18_col4, #T_d2c4f_row18_col5, #T_d2c4f_row18_col6, #T_d2c4f_row19_col0, #T_d2c4f_row19_col1, #T_d2c4f_row19_col2, #T_d2c4f_row19_col3, #T_d2c4f_row19_col4, #T_d2c4f_row19_col5, #T_d2c4f_row19_col6 {
#   text-align: left;
# }
# #T_d2c4f_row0_col1, #T_d2c4f_row0_col2, #T_d2c4f_row0_col3, #T_d2c4f_row0_col4, #T_d2c4f_row0_col5, #T_d2c4f_row0_col6, #T_d2c4f_row1_col4, #T_d2c4f_row1_col5, #T_d2c4f_row1_col6, #T_d2c4f_row2_col4, #T_d2c4f_row2_col5, #T_d2c4f_row2_col6, #T_d2c4f_row3_col5, #T_d2c4f_row3_col6, #T_d2c4f_row4_col6, #T_d2c4f_row5_col5, #T_d2c4f_row5_col6, #T_d2c4f_row6_col5, #T_d2c4f_row6_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d2c4f_row0_col7, #T_d2c4f_row1_col7, #T_d2c4f_row2_col7, #T_d2c4f_row3_col7, #T_d2c4f_row4_col7, #T_d2c4f_row5_col7, #T_d2c4f_row6_col7, #T_d2c4f_row7_col7, #T_d2c4f_row8_col7, #T_d2c4f_row9_col7, #T_d2c4f_row11_col7, #T_d2c4f_row12_col7, #T_d2c4f_row13_col7, #T_d2c4f_row14_col7, #T_d2c4f_row15_col7, #T_d2c4f_row16_col7, #T_d2c4f_row17_col7, #T_d2c4f_row18_col7, #T_d2c4f_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d2c4f_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d2c4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2c4f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d2c4f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d2c4f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d2c4f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d2c4f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d2c4f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d2c4f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d2c4f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2c4f_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_d2c4f_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_d2c4f_row0_col1" class="data row0 col1" >20.1438</td>
#       <td id="T_d2c4f_row0_col2" class="data row0 col2" >708.8757</td>
#       <td id="T_d2c4f_row0_col3" class="data row0 col3" >26.4896</td>
#       <td id="T_d2c4f_row0_col4" class="data row0 col4" >0.1054</td>
#       <td id="T_d2c4f_row0_col5" class="data row0 col5" >0.2639</td>
#       <td id="T_d2c4f_row0_col6" class="data row0 col6" >0.2096</td>
#       <td id="T_d2c4f_row0_col7" class="data row0 col7" >501.3760</td>
#     </tr>
#     <tr>
#       <th id="T_d2c4f_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_d2c4f_row1_col0" class="data row1 col0" >Decision Tree Regressor</td>
#       <td id="T_d2c4f_row1_col1" class="data row1 col1" >20.1439</td>
#       <td id="T_d2c4f_row1_col2" class="data row1 col2" >708.8830</td>
#       <td id="T_d2c4f_row1_col3" class="data row1 col3" >26.4897</td>
#       <td id="T_d2c4f_row1_col4" class="data row1 col4" >0.1054</td>
#       <td id="T_d2c4f_row1_col5" class="data row1 col5" >0.2639</td>
#       <td id="T_d2c4f_row1_col6" class="data row1 col6" >0.2096</td>
#       <td id="T_d2c4f_row1_col7" class="data row1 col7" >14.3300</td>
#     </tr>
#     <tr>
#       <th id="T_d2c4f_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_d2c4f_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_d2c4f_row2_col1" class="data row2 col1" >20.1439</td>
#       <td id="T_d2c4f_row2_col2" class="data row2 col2" >708.8831</td>
#       <td id="T_d2c4f_row2_col3" class="data row2 col3" >26.4897</td>
#       <td id="T_d2c4f_row2_col4" class="data row2 col4" >0.1054</td>
#       <td id="T_d2c4f_row2_col5" class="data row2 col5" >0.2639</td>
#       <td id="T_d2c4f_row2_col6" class="data row2 col6" >0.2096</td>
#       <td id="T_d2c4f_row2_col7" class="data row2 col7" >175.3520</td>
#     </tr>
#     <tr>
#       <th id="T_d2c4f_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_d2c4f_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_d2c4f_row3_col1" class="data row3 col1" >20.1447</td>
#       <td id="T_d2c4f_row3_col2" class="data row3 col2" >709.1982</td>
#       <td id="T_d2c4f_row3_col3" class="data row3 col3" >26.4952</td>
#       <td id="T_d2c4f_row3_col4" class="data row3 col4" >0.1050</td>
#       <td id="T_d2c4f_row3_col5" class="data row3 col5" >0.2639</td>
#       <td id="T_d2c4f_row3_col6" class="data row3 col6" >0.2096</td>
#       <td id="T_d2c4f_row3_col7" class="data row3 col7" >97.5280</td>
#     </tr>
#     <tr>
#       <th id="T_d2c4f_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_d2c4f_row4_col0" class="data row4 col0" >CatBoost Regressor</td>
#       <td id="T_d2c4f_row4_col1" class="data row4 col1" >20.1454</td>
#       <td id="T_d2c4f_row4_col2" class="data row4 col2" >709.3287</td>
#       <td id="T_d2c4f_row4_col3" class="data row4 col3" >26.4979</td>
#       <td id="T_d2c4f_row4_col4" class="data row4 col4" >0.1049</td>
#       <td id="T_d2c4f_row4_col5" class="data row4 col5" >0.2640</td>
#       <td id="T_d2c4f_row4_col6" class="data row4 col6" >0.2096</td>
#       <td id="T_d2c4f_row4_col7" class="data row4 col7" >492.9820</td>
#     </tr>
#     <tr>
#       <th id="T_d2c4f_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_d2c4f_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d2c4f_row5_col1" class="data row5 col1" >20.1454</td>
#       <td id="T_d2c4f_row5_col2" class="data row5 col2" >709.2191</td>
#       <td id="T_d2c4

# %%
prediction_holdout = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_82bc8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82bc8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_82bc8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_82bc8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_82bc8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_82bc8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_82bc8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_82bc8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82bc8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82bc8_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_82bc8_row0_col1" class="data row0 col1" >20.7658</td>
#       <td id="T_82bc8_row0_col2" class="data row0 col2" >759.3743</td>
#       <td id="T_82bc8_row0_col3" class="data row0 col3" >27.5567</td>
#       <td id="T_82bc8_row0_col4" class="data row0 col4" >0.0917</td>
#       <td id="T_82bc8_row0_col5" class="data row0 col5" >0.2811</td>
#       <td id="T_82bc8_row0_col6" class="data row0 col6" >0.2294</td>
#     </tr>
#   </tbody>
# </table>

# %%
# plot_model(best, plot='forecast', data_kwargs={'fh': 24})

# %% [markdown]
# ## Approach 2: CNN

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %%
def Model(input_dim, activation, num_class):
    model = Sequential()

    model.add(Dense(1024, input_dim = input_dim))
    model.add(Activation(activation))
    model.add(Dropout(0.5))

    model.add(Dense(512)) 
    model.add(Activation(activation))
    model.add(Dropout(0.5))

    model.add(Dense(64))    
    model.add(Activation(activation))
    model.add(Dropout(0.25))

    model.add(Dense(num_class))    
    model.add(Activation('linear'))
    
    model.compile(loss='Huber',
                  optimizer=optimizers.Adam(lr = 0.001),
                  metrics=['MeanAbsoluteError']
                 )
    return model

# %%
input_dim = X_train.shape[1]
activation = 'relu'
classes = 1
model = Model(input_dim=input_dim, activation=activation, num_class=classes)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              2048
# _________________________________________________________________
# activation (Activation)      (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                32832
# _________________________________________________________________
# activation_2 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 559,745
# Trainable params: 559,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model
history = model.fit(X_train[:1000000], # using the first 1million rows for speed.
                    y_train[:1000000].squeeze(),
                    epochs=5,
                    batch_size=128,
                    verbose = 1
                   )
# Out:
# Epoch 1/5
# 7813/7813 [==============================] - 52s 7ms/step - loss: 22.4909 - mean_absolute_error: 22.9859
# Epoch 2/5
# 7813/7813 [==============================] - 60s 8ms/step - loss: 20.9061 - mean_absolute_error: 21.4006
# Epoch 3/5
# 7813/7813 [==============================] - 59s 7ms/step - loss: 20.5952 - mean_absolute_error: 21.0896
# Epoch 4/5
# 7813/7813 [==============================] - 58s 7ms/step - loss: 20.4277 - mean_absolute_error: 20.9220
# Epoch 5/5
# 7813/7813 [==============================] - 59s 8ms/step - loss: 20.2889 - mean_absolute_error: 20.7831

# %%
#Predicting on the test set using the nn(neural network) model
nn_predictions = model.predict(X_test[:1000000])
error = rmse(y_test[:1000000], nn_predictions)
print(f'Neural Net RMSE: {error}')
# Out:
# Neural Net RMSE: 26.02794643182251

# %%
plt.title('Train loss against mean_absolute_error')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(history.history['loss'])
plt.plot(history.history['mean_absolute_error'])
plt.legend(['Loss', 'Mean_absolute_error'])

# %%
# Visualize predicted BP and the True BP
plt.title("===True BP values Vs Predicted BP values===")
plt.xlabel('Number of samples taken')
plt.ylabel('BP values')
plt.plot(y_test[:100]) #only plotting 100 samples
plt.plot(nn_predictions[:100])
plt.legend(['True_BP', 'Predicted_BP'])
